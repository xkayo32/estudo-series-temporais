# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import datetime
from matplotlib.pylab import rcParams

# %%
rcParams['figure.figsize'] = 15 , 6

# %% [markdown]
# # Série anual

# %%
# Série de 1980 a 2020
np.random.seed(10)
dados1 = np.random.normal(0,1,41) # média 0, desvio padrão 1 , valores 41
dados1
# Out:
# array([ 1.3315865 ,  0.71527897, -1.54540029, -0.00838385,  0.62133597,
#        -0.72008556,  0.26551159,  0.10854853,  0.00429143, -0.17460021,
#         0.43302619,  1.20303737, -0.96506567,  1.02827408,  0.22863013,
#         0.44513761, -1.13660221,  0.13513688,  1.484537  , -1.07980489,
#        -1.97772828, -1.7433723 ,  0.26607016,  2.38496733,  1.12369125,
#         1.67262221,  0.09914922,  1.39799638, -0.27124799,  0.61320418,
#        -0.26731719, -0.54930901,  0.1327083 , -0.47614201,  1.30847308,
#         0.19501328,  0.40020999, -0.33763234,  1.25647226, -0.7319695 ,
#         0.66023155])

# %%
# Criando séries do dados gerados
serie = pd.Series(dados1)
serie.plot()
# Out:
# <AxesSubplot: >

# %%
# Criando os indices de 1980 a 2020
indice = pd.date_range('1980',periods=len(dados1),freq='Y')
df_serie = pd.Series(serie.values,index=indice)

# %%
# Dados estatísticos 
df_serie.describe()
# Out:
# count    41.000000
# mean      0.183670
# std       0.964847
# min      -1.977728
# 25%      -0.337632
# 50%       0.195013
# 75%       0.715279
# max       2.384967
# dtype: float64

# %%
df_serie.plot();

# %%
stats.probplot(df_serie,dist='norm',plot=plt)
plt.title('Normal QQ plot')
plt.show()

# %% [markdown]
# **Teste Shapiro-Wilk**
#
# Critérios:
# > Nível de significância de 0,005 ou 5% (mais utilizado)
# > quando p > 0,05 (distribuição normal).

# %%
e,p = stats.shapiro(df_serie)
print(f'Estatística de teste: {e}\np-Valor: {p}')
# Out:
# Estatística de teste: 0.9869343638420105
# p-Valor: 0.9118920564651489

# %% [markdown]
# # Série mensal

# %%
np.random.seed(6)
dados2 = np.random.normal(0,1,72)
dados2
# Out:
# array([-0.31178367,  0.72900392,  0.21782079, -0.8990918 , -2.48678065,
#         0.91325152,  1.12706373, -1.51409323,  1.63929108, -0.4298936 ,
#         2.63128056,  0.60182225, -0.33588161,  1.23773784,  0.11112817,
#         0.12915125,  0.07612761, -0.15512816,  0.63422534,  0.810655  ,
#         0.35480861,  1.81259031, -1.3564758 , -0.46363197,  0.82465384,
#        -1.17643148,  1.56448966,  0.71270509, -0.1810066 ,  0.53419953,
#        -0.58661296, -1.48185327,  0.85724762,  0.94309899,  0.11444143,
#        -0.02195668, -2.12714455, -0.83440747, -0.46550831,  0.23371059,
#         1.38503523, -0.51962709, -0.78015214,  0.95560959, -0.12673638,
#        -1.36861282,  1.21848065, -0.85750144, -0.56147088, -1.0335199 ,
#         0.35877096,  1.07368134, -0.37550472,  0.39636757, -0.47144628,
#         2.33660781,  1.50278553, -0.59545972,  0.52834106,  0.9398248 ,
#         0.42628539, -0.75815703, -0.16236698,  0.72680996,  0.44408297,
# ...

# %%
data = np.array('2015-01',dtype=np.datetime64())
data = data + np.arange(72)

# %%
df_serie2 = pd.Series(dados2,index=data)

# %%
df_serie2.head()
# Out:
# 2015-01-01   -0.311784
# 2015-02-01    0.729004
# 2015-03-01    0.217821
# 2015-04-01   -0.899092
# 2015-05-01   -2.486781
# dtype: float64

# %%
df_serie2.describe()
# Out:
# count    72.000000
# mean      0.092709
# std       1.022496
# min      -2.486781
# 25%      -0.567756
# 50%       0.151507
# 75%       0.814155
# max       2.631281
# dtype: float64

# %%
df_serie2.plot()
plt.show()

# %%
stats.probplot(df_serie2,dist='norm',plot=plt)
plt.title('Normal QQ plot')
plt.show()

# %% [markdown]
# **Teste Shapiro-Wilk**
#
# Critérios:
# > Nível de significância de 0,005 ou 5% (mais utilizado)
# > quando p > 0,05 (distribuição normal).

# %%
e,p = stats.shapiro(df_serie2)
print(f'Estatística de teste: {e}\np-Valor: {p}')
# Out:
# Estatística de teste: 0.9929383993148804
# p-Valor: 0.9612120985984802
